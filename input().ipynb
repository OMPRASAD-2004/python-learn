# %% [markdown]
# # framework,module,package.function
# # math module,input()

# %%
sqrt(25)
# Out:
# 5.0

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.ceil(3.5)
# Out:
# 4

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.9)
# Out:
# 5

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
m.floor(3.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 m.floor(3.4)
#
# NameError: name 'm' is not defined

# %%
import math as m
print(m.floor(3.4))
print(m.ceil(3.4))                   #math funtion decear as math not m
print(m.pow(3,4))                   #key word=import,as
print(m.sqrt(34))
# Out:
# 3
# 4
# 81.0
# 5.830951894845301

# %%
from math import pow, floor,ceil,sqrt
print(floor(3.4))
print(ceil(3.4))                   #this is called code optimization=here did not required declear every time onece you declare then it work every time
print(pow(3,4))                  #that wise i used here from()
print(sqrt(34))
# Out:
# 3
# 4
# 81.0
# 5.830951894845301

# %%
from math import *
print(floor(3.4))
print(ceil(3.4))                   #here didnot requried one by one math module declear here declear only (*) it will start all math module function
print(pow(3,4))                  
print(sqrt(34))
# Out:
# 3
# 4
# 81.0
# 5.830951894845301

# %% [markdown]
# # input()

# %%
x=input()
x
# Out:
#  5
# '5'

# %%
x=input()
y=input()                              #input allows give string that wise it give 5+3=53
z=x+y
print(z)
# Out:
#  5
#  3
# 53

# %%
x=input()
y=input()                     #in str there will be not work multiplication,sub,div only addition is happening
z=x*y
print(z)
# Out:
#  5
#  3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 x=input()
#       2 y=input()
# ----> 3 z=x*y
#       4 print(z)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
x=input('enter the 1st number')
y=input('enter the 2nd number')
z=x+y
print(z)
# Out:
# enter the 1st number 5
# enter the 2nd number 6
# 56

# %%
x=input('user_name')
y=input('password')
z=x+y
print(z)
# Out:
# user_name omdash
# password Om@2004
# omdashOm@2004

# %%
x1=input()
a1=int(x1)
y1=input()
b1=int(y1)
z=a1+b1
print(z)
# Out:
#  5
#  3
# 8

# %%
x=int(input('enter the 1st number'))
y=int(input('enter the 2nd number'))
z=x+y
print(z)
# Out:
# enter the 1st number 5
# enter the 2nd number 3
# 8

# %%
st=input('enter a string ')[0]
print(st)
# Out:
# enter a string  hello
# h

# %%
st=input('enter a string ')[8:]
print(st)                                    #prompt eanginearing we will be used this input()
# Out:
# enter a string  905881066977
# 6977

# %%
result=input('enter an expr')
print(result)
# Out:
# enter an expr 2+3+5-2
# 2+3+5-2

# %% [markdown]
# # eval

# %%
result=eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 2+3+4-2
# 7
