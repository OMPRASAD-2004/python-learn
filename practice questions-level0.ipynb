# %% [markdown]
# # practice questions-level0

# %%
-3>>13
# Out:
# -1

# %%
5&3
# Out:
# 1

# %%
5|3
# Out:
# 7

# %%
~5
# Out:
# -6

# %%
0&1
# Out:
# 0

# %%
10<<1
# Out:
# 20

# %%
10>>1
# Out:
# 5

# %%
a=int(input('enter the value'))
a=a&1==0
print(a)
# Out:
# enter the value 4
# True

# %%
a=int(input('enter the value'))
b=int(input('enter the value'))
a=a^b
b=a^b
a=a^b
print(a)
print(b)
# Out:
# enter the value 5
# enter the value 6
# 6
# 5

# %%
((3 ^ 5) << 1) & 3
# Out:
# 0

# %%
a=int(input('enter the value'))
area=(((((3)**0.5))/4)*(a**2))      #sqrt(3)/4)*(a**2)
print(area)
# Out:
# enter the value 5
# 10.825317547305483

# %%
P = float(input("Enter the principal amount: "))
R = float(input("Enter the annual interest rate (in %): "))
T = float(input("Enter the time (in years): "))
simpleinterest=P*R*T
print(simpleinterest)
# Out:
# Enter the principal amount:  1000
# Enter the annual interest rate (in %):  10
# Enter the time (in years):  2
# 20000.0

# %%
a=float(input('enter the value:'))
b=float(input('enter the value:'))
c=float(input('enter the value:'))
d=b**2- 4*a*c
print(d)
# Out:
# enter the value: 3
# enter the value: 4
# enter the value: 5
# -44.0

# %% [markdown]
# import math
# a = float(input("Enter coefficient a: "))
# b = float(input("Enter coefficient b: "))
# c = float(input("Enter coefficient c: "))
# d = b**2 - 4*a*c
# if d > 0:
#     root1 = (-b + math.sqrt(d)) / (2*a)
#     root2 = (-b - math.sqrt(d)) / (2*a)
#     print("Two distinct real roots:")
#     print("Root 1 =", root1)
#     print("Root 2 =", root2)
# elif d == 0:
#     root = -b / (2*a)
#     print("One real root (repeated):")
#     print("Root =", root)
# else:
#     realPart = -b / (2*a)
#     imagPart = math.sqrt(-d) / (2*a)
#     print("Complex roots:")
#     print("Root 1 =", realPart, "+", imagPart, "i")
#     print("Root 2 =", realPart, "-", imagPart, "i")

# %%
P = float(input("Enter the principal amount: "))                            # CI = P * ( (1 + R/100) ^ T )
R = float(input("Enter the annual interest rate (in %): "))
T = float(input("Enter the time (in years): "))
N = int(input("Enter the number of times interest is compounded per year: "))
A = P * (1 + R/(100*N))**(N*T)  
CI = A - P                       

print("Final Amount =", round(A, 2))
print("Compound Interest =", round(CI, 2))
# Out:
# Enter the principal amount:  1000
# Enter the annual interest rate (in %):  10
# Enter the time (in years):  2
# Enter the number of times interest is compounded per year:  4
# Final Amount = 1218.4
# Compound Interest = 218.4

# %%
n=int(input('enter the value'))
nn=int(str(n)*2)
nnn=int(str(n)*3)
n=n+nn+nnn
print(n)
# Out:
# enter the value 5
# 615

# %%
r=float(input('enter the sphere radius value:'))
pai=3.141
volume=4/3*pai*r**3
print('volume:',volume)
# Out:
# enter the sphere radius value: 6
# volume: 904.608

# %%
x = 4
y = 3
result = (x + y) ** 2
print("result:",result)
# Out:
# result: 49

# %%
x1=float(input("enter the vale of x1"))
y1=float(input("enter the vale of y1"))
x2=float(input("enter the vale of x2"))
y2=float(input("enter the vale of y2"))
distance=((((y2-y1)**2)+((x2-x1)**2))**0.5)
print("distance:",distance)
# Out:
# enter the vale of x1 2
# enter the vale of y1 3
# enter the vale of x2 5
# enter the vale of y2 7
# distance: 5.0

# %%
feet=int(input("Enter the hight value in feet"))
inches=int(input("Enter the hight value in inches"))
height_cm=(feet*30.48)+(inches*2.54)
print("height_cm :",height_cm)
# Out:
# Enter the hight value in feet 6
# Enter the hight value in inches 11
# height_cm : 210.82

# %%
h=float(input("enter the vale of h"))
b=float(input("enter the vale of b"))
hypothenious=(((h)**2+(b)**2)**0.5)
print("hypothenious",hypothenious)
# Out:
# enter the vale of h 3
# enter the vale of b 4
# hypothenious 5.0

# %%
a=int(input('enter the value'))
b=int(input('enter the value'))
c=int(input('enter the value'))
a=a^c
b=b^a
c=c^b
print(a)
print(b)
# Out:
# enter the value 3
# enter the value 4
# enter the value 5
# 6
# 2

# %%
# write a program to check even or not

# %%
a=int(input("enter the value"))
if a%2==0:
    print("the number even")
if a%2!=0:
     print("the number odd")
# Out:
# enter the value 5
# the number odd
