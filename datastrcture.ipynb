# %% [markdown]
# # data structure

# %% [markdown]
# # list datastructure

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10, 10, 10, 10, 10]

# %%
len(l)
# Out:
# 4

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 9

# %%
# list  deffine with[]
# append () adding value in list up to n number

# %%
l
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50]

# %%
l.append(10)
l                                     # in list duplict value is allow
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]

# %%
l1=[10,3.5,True,1+2j,'om']
l1                                  # in list can add different type of data type
# Out:
# [10, 3.5, True, (1+2j), 'om']

# %%
l1.append([1,2,3])                  # list in list called nested list
l1
# Out:
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]

# %%
print(l)
print(l1)             #list is growable
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]

# %%
l
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]

# %%
l3=l.copy()      # from one list to another list
l3
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]

# %%
l==l3
# Out:
# True

# %%
len(l)==len(l3)
# Out:
# True

# %%
id(l)==id(l3)
# Out:
# False

# %%
id(l)!=id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 2439736079552
# 2439738540416

# %%
# copy,append,clear,deleat,count,index

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]

# %%
l3.clear()
                  #clear all vale from l3

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]
# []

# %%
del l3               # delet all place in l3 from memory

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 print(l)
#       2 print(l1)
# ----> 3 print(l3)
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]

# %%
l.count(10)     # count the vale avalable in list how many time it showing
# Out:
# 6

# %%
l.extend(l1)
l
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  3.5,
#  True,
#  (1+2j),
#  'om',
#  [1, 2, 3]]

# %%
print(len(l))
print(len(l1))
# Out:
# 16
# 6

# %%
a1=[1,2,3]
b1=[4,5,6]                                #we merge the 2 list in one

# %%
a1.extend(b1)
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [10, 10, 10, 10, 10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+2j), 'om', [1, 2, 3]]
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]

# %%
l. index(20)
# Out:
# 5

# %%
l1. index(1+2j)
# Out:
# 3

# %%
l1. index('om')       # it is show the value avalable in which place
# Out:
# 4

# %%
# indexing

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]

# %%
l1[4]
# Out:
# 'om'

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1[3:]
# Out:
# [(1+2j), 'om', [1, 2, 3]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'om']

# %%
l1[-3]
# Out:
# (1+2j)

# %%
l1[-3:]
# Out:
# [(1+2j), 'om', [1, 2, 3]]

# %%
l1[::-1]
# Out:
# [[1, 2, 3], 'om', (1+2j), True, 3.5, 10]

# %%
l1[::-2]
# Out:
# [[1, 2, 3], (1+2j), 3.5]

# %%
l1[4]
# Out:
# 'om'

# %%
print(l1[4][0])           # nested indexing(index in index)
# Out:
# o

# %%
print(l1[4][1])
# Out:
# m

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'om', [1, 2, 3]]

# %%
l1[0]=100          # list is muteble ( the list is allow for edit )

# %%
l1
# Out:
# [100, 3.5, True, (1+2j), 'om', [1, 2, 3]]
