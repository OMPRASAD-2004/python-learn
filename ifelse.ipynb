# %%
# wAP to find the area of the equilitral trangle

# %%
s=float(input("enter the trangle side"))
area=((3**0.5)/4)*(s**2)
print("area:",area)
# Out:
# enter the trangle side 5
# area: 10.825317547305483

# %%
# contral unit

# %% [markdown]
# #cpu- cpu responsing for perfoerming all the operation in computer
# #these all programing happening on main memory
# #program- set of interaction written in programing language
# #each instruction consist of number of micro-instruction
# #cpu is able to execute one micro in showing per clock cycle
# #cpu execution flow is seqence
# #controal str are use the flow of the execution of the program
# #by keeping the condition
# #in a python ther is 4 type of control str
# 1-simple if
# 2-if ----else
# 3-if --elif----else
# 4-nested if

# %%
# 1-feath operation-'+'
# 2- decoder-addition
#3-circiet-adder

# %% [markdown]
# 1.simple if
# if without else block is a simple if.
# if--->keyword
# syntax--
#    if condition:
#       statement
#     if-->keyword
#     condition-->decides a statement will execute or not
#     :-->end

# %% [markdown]
# # if

# %%
a=int(input("enter the value"))
if a>5:
    print("hello")
# Out:
# enter the value 6
# hello

# %%
a=int(input("enter the value"))
if a>5:
    print("hello")
print("hoga kya??")
# Out:
# enter the value 4
# hoga kya??

# %%
a=int(input("enter the value"))
if a>7:
    pass
print("bolo")
# Out:
# enter the value 7
# bolo

# %%
# write a program to check even or not

# %%
a=int(input("enter the value"))
if a%2==0:
    print("the number even")
if a%2!=0:
     print("the number odd")
# Out:
# enter the value 5
# the number odd

# %%
a=int(input("enter the value"))
if a&1==0:
    print("the number even")                           # according bitwise  operator
if a&1!=0:
     print("the number odd")
# Out:
# enter the value 5
# the number odd

# %%
# wap garater value in 3 number
a=int(input("enter the value"))
b=int(input("enter the value"))
c=int(input("enter the value"))
if a>b and a>c:
    print ("a is grater value")
if b>a and b>c:
     print ("b is grater value")
if c>a and c>b:
     print ("c is grater value")
# Out:
# enter the value 7
# enter the value 12
# enter the value 3
# b is grater value

# %% [markdown]
# # ifelse

# %%
a=int(input("enter the value"))
if a&1==0:
    print("the number even")                           # among these two block one block is getting execute either if or else
else:                                                   #
     print("the number odd")
# Out:
# enter the value 5
# the number odd

# %%
#wap to check a point is lieing inside ,outside or on the circile radius and point(x,y) is a input.
R=float(input("enter the value R:"))
X=float(input("enter the value X:"))
Y=float(input("enter the value Y:"))
d=((X**2)+(Y**2))**0.5
if R==d:
    print("on the circle")
if R<d:
    print("outside the circle")
if R>d:
    print("inside the circle")
# Out:
# enter the value R: 14
# enter the value X: 4.5
# enter the value Y: 3.4
# inside the circle

# %%
wap to check a point lies in which cordinate

# %%
x=float(input("enter the value X:"))
y=float(input("enter the value Y:"))
if x>0 and y>0:
    print("1st qudrat")
if x<0 and y>0:
    print("2nd qudrat")
if x<0 and y<0:
    print("3rd qudrat")
if x>0 and y<0:
    print("4th qudrat")
# Out:
# enter the value X: -4
# enter the value Y: -5
# 3rd qudrat
