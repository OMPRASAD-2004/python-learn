# %% [markdown]
# # assignment2

# %%
a=int(input("enter the value"))
b=int(input("enter the value"))
if a==b:
    print("two values are same")
else:
    print("two values are not same")
# Out:
# enter the value 12
# enter the value 50
# two values are not same

# %%
n=int(input("enter the value"))
if n%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# enter the value 1
# odd number

# %%
n=int(input("enter the value"))
if n>=0:
    print("positive")
else:
    print("negative")
# Out:
# enter the value 15
# positive

# %%
n=int(input("enter the year"))
if (n%400==0) or (n%4==0 and n%100!=0):
    print("leap year")
else:
    print("not a leap year")
# Out:
# enter the year 1900
# not a leap year

# %%
n=int(input("enter the year"))
if n>=18:
    print("you eligible for voting")
else:
    print("you not eligible for voting")
# Out:
# enter the year 21
# you eligible for voting

# %%
m = int(input("Enter the value of m: "))
if m > 0:
    n = 1
elif m == 0:
    n = 0
else:
    n = -1
print(f"The value of n = {n}")
# Out:
# Enter the value of m:  -5
# The value of n = -1

# %%
height=float(input("enter the hight"))
if height <= 140:
    print("The person is Dwarf.")
elif 141 <= height <= 150:
    print("The person is Short.")
elif 151 <= height <= 165:
    print("The person is Average height.")
elif 166 <= height <= 195:
    print("The person is Tall.")
else:
    print("The person is Very tall.")
# Out:
# enter the hight 135
# The person is Dwarf.

# %%
a=int(input("enter the a value"))
b=int(input("enter the b value"))
c=int(input("enter the c value"))
if a>b and a>c:
    print ("a is gratter value")
if b>a and b>c:
    print("b is grater value")
if c>a and c>b:
    print("c is grater value")
# Out:
# enter the a value 12
# enter the b value 25
# enter the c value 52
# c is grater value

# %%
x=int(input("enter the value of x :"))
y=int(input("enter the value of y :"))
if x>0 and y>0:
    print("x and y value layes in 1st quadrant")
elif x<0 and y>0:
    print("x and y value layes in 2nd quadrant")
elif x<0 and y<0:
    print("x and y value layes in 3rd quadrant")
elif x>0 and y<0:
    print("x and y value layes in 4th quadrant")
# Out:
# enter the value of x : -3
# enter the value of y : 4
# x and y value layes in 2nd quadrant

# %%
rollno=int(input("enter the rollno of students"))
name=input("enter a name of student")
s1=int(input("enter marks of physics"))
s2=int(input("enter marks of chemistry"))
s3=int(input("enter marks of maths"))
total_marks=s1+s2+s3
percentage=((s1+s2+s3)/300)*100
if percentage<=80:
    print("not eligible for admission")
else:
    print("eligible for admission")
# Out:
# enter the rollno of students 2202112
# enter a name of student om
# enter marks of physics 65
# enter marks of chemistry 51
# enter marks of maths 72
# not eligible for admission

# %%
rollno=int(input("enter the rollno of students"))
name=input("enter a name of student")
s1=int(input("enter marks of physics"))
s2=int(input("enter marks of chemistry"))
s3=int(input("enter marks of maths"))
total_marks=s1+s2+s3
percentage=((s1+s2+s3)/300)*100
if percentage>=90:
    print("outstanding")
elif percentage>=80:
    print("FIRST CLASS")
elif percentage>=60:
    print("SECOND CLASS")
else:
    print("THIRD CLASS")
print("total mark:" ,total_marks)
print("percentage :" ,percentage)
# Out:
# enter the rollno of students 784
# enter a name of student james
# enter marks of physics 70
# enter marks of chemistry 80
# enter marks of maths 90
# FIRST CLASS
# total mark: 240
# percentage : 80.0

# %%
temp=int(input("enter a tempearture in cetigrades"))
if temp<0:
    print("Freezing weather")
elif temp>=0 and temp<10:
    print("Very Cold weather")
elif temp>=10 and temp<20:
    print("Cold weather")
elif temp>=20 and temp<30:
    print("Normal temepearture")
elif temp>=30 and temp<40:
    print("Hot weather")
else:
    print("very hot weather")
# Out:
# enter a tempearture in cetigrades -2
# Freezing weather

# %%
a = int(input("Enter first angle: "))
b = int(input("Enter second angle: "))
c = int(input("Enter third angle: "))
if a + b + c == 180:
    if a == b == c:
        print("This is an equilateral triangle.")
    elif a == b or b == c or a == c:
        print("This is an isosceles triangle.")
    else:
        print("This is a scalene triangle.")
        
else:
    print("The angles do not form a valid triangle.")
# Out:
# Enter first angle:  90
# Enter second angle:  45
# Enter third angle:  45
# This is an isosceles triangle.

# %%
a = int(input("Enter first angle: "))
b = int(input("Enter second angle: "))
c = int(input("Enter third angle: "))
if a + b + c == 180:
    if a == b == c:
        print("This is an equilateral triangle.")
        
    elif a == b or b == c or a == c:
        print("This is an isosceles triangle.")
    else:
        print("This is a scalene triangle.")
        
else:
    print("The angles do not form a valid triangle.")
# Out:
# Enter first angle:  40
# Enter second angle:  55
# Enter third angle:  65
# The angles do not form a valid triangle.

# %%
n=input("enter the value")
if n.isalpha():
    print("it is alphabit type")
elif n.isdigit():
    print("it is number type")
else:
    print("this is special character")
# Out:
# enter the value $
# this is special character

# %%
ch = input("Enter an alphabet: ")
ch = ch.lower()

if ch in ('a', 'e', 'i', 'o', 'u'):
    print("The alphabet is a vowel.")
elif ch.isalpha():
    print("The alphabet is a consonant.")
else:
    print("Invalid input! Please enter an alphabet.")
# Out:
# Enter an alphabet:  a
# The alphabet is a vowel.

# %%
cost_price = int(input("Enter cost price: "))
selling_price = int(input("Enter selling price: "))

if selling_price > cost_price:
    profit = selling_price - cost_price
    print("You can booked your profit amount :", profit)
elif cost_price > selling_price:
    loss = cost_price - selling_price
    print("You can booked your loss amount :", loss)
else:
    print("No profit, no loss.")
# Out:
# Enter cost price:  700
# Enter selling price:  500
# You can booked your loss amount : 200

# %%
cust_id=int(input("enter a customer id"))
name=input("enter a name of a customer")
units=int(input("enter the units consumed"))
amount=0.0
if units<=199:
    amount=units*1.20
elif units>=200 and units<400:
    amount=units*1.50
elif units>=400 and units<600:
    amount=units*1.80
else:
    amount=units*2.00
if amount>400:
    amount+=(15/100)*amount
if amount<100:
    amount=100
print("customer_id:",cust_id)
print("Name:",name)
print("units:",units)
print("Amount:",amount)
# Out:
# enter a customer id 1001
# enter a name of a customer james
# enter the units consumed 800
# customer_id: 1001
# Name: james
# units: 800
# Amount: 1840.0

# %%
grade=input("enter the grade")
if grade=="E":
    print("excellent")
elif grade=="V":
    print("Very Good")
elif grade=="G":
    print("Good")
elif grade=="A":
    print("Average")
elif grade=="F":
    print("Fail")
# Out:
# enter the grade A
# Average

# %%
day=int(input("enter the number"))
if day==1:
    print("sunday")
elif day==2:
    print("monday")
elif day==3:
    print("tueday")
elif day==4:
    print("wedday")
elif day==5:
    print("thrday")
elif day==6:
    print("friday")
elif day==7:
    print("satday")
# Out:
# enter the number 5
# thrday

# %%
digit = int(input("Enter a digit (0-9): "))

if digit == 0:
    print("Zero")
elif digit == 1:
    print("One")
elif digit == 2:
    print("Two")
elif digit == 3:
    print("Three")
elif digit == 4:
    print("Four")
elif digit == 5:
    print("Five")
elif digit == 6:
    print("Six")
elif digit == 7:
    print("Seven")
elif digit == 8:
    print("Eight")
elif digit == 9:
    print("Nine")
else:
    print("Invalid input! Please enter a single digit between 0 and 9.")
# Out:
# Enter a digit (0-9):  8
# Eight

# %%
# Python program to display number of days in a month

month = int(input("Enter month number (1-12): "))

if month == 1:
    print("Month have 31 days")
elif month == 2:
    print("Month have 28 or 29 days")
elif month == 3:
    print("Month have 31 days")
elif month == 4:
    print("Month have 30 days")
elif month == 5:
    print("Month have 31 days")
elif month == 6:
    print("Month have 30 days")
elif month == 7:
    print("Month have 31 days")
elif month == 8:
    print("Month have 31 days")
elif month == 9:
    print("Month have 30 days")
elif month == 10:
    print("Month have 31 days")
elif month == 11:
    print("Month have 30 days")
elif month == 12:
    print("Month have 31 days")
else:
    print("Invalid month number! Please enter between 1 and 12.")
# Out:
# Enter month number (1-12):  7
# Month have 31 days
